# %%
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        # we are given an array nums. We need to first square all the elements of the array and then we need to sort them
